# %% [markdown]
# # Project :  E-commerce Furniture Dataset 2024 Analysis

# %% [markdown]
# ## Introduction

# %%
from IPython.display import Image
Image(filename="C:/Users/sunde/OneDrive/Desktop/project3/furniture image.jpg")

# %% [markdown]
# ## Objective

# %% [markdown]
# ### Analyzing e-commerce furniture data helps identify sales trends, customer preferences, and inventory demands. It optimizes pricing, marketing strategies, and supply chain efficiency while enhancing user experiences. This drives better decision-making, boosts revenue, and fosters customer satisfaction in competitive markets.

# %% [markdown]
# ## Importing necessary libraries

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading data

# %%
df=pd.read_csv('C:/Users/sunde/OneDrive/Desktop/project3/ecommerce_furniture_dataset_2024.csv')

# %%
df
# Out:
#                                            productTitle originalPrice  \
# 0     Dresser For Bedroom With 9 Fabric Drawers Ward...           NaN
# 1     Outdoor Conversation Set 4 Pieces Patio Furnit...           NaN
# 2     Desser For Bedroom With 7 Fabric Drawers Organ...         $78.4
# 3     Modern Accent Boucle Chair,Upholstered Tufted ...           NaN
# 4     Small Unit Simple Computer Desk Household Wood...        $48.82
# ...                                                 ...           ...
# 1995  Modern TV Stand Entertainment Center with Two ...           NaN
# 1996  Large Wardrobe Armoire Closet with 3 Doors, Fr...           NaN
# 1997  Velvet Futon Sofa Bed, 73-inch Sleeper Couch w...           NaN
# 1998  Furniture Acrylic Coffee Table Transparent Liv...           NaN
# 1999  Bed Frane Bamboo and Metal Platform Bed Frame ...           NaN
#
#         price  sold        tagText
# 0      $46.79   600  Free shipping
# 1     $169.72     0  Free shipping
# ...

# %%
#head method 
df.head()
# Out:
#                                         productTitle originalPrice    price  \
# 0  Dresser For Bedroom With 9 Fabric Drawers Ward...           NaN   $46.79
# 1  Outdoor Conversation Set 4 Pieces Patio Furnit...           NaN  $169.72
# 2  Desser For Bedroom With 7 Fabric Drawers Organ...         $78.4   $39.46
# 3  Modern Accent Boucle Chair,Upholstered Tufted ...           NaN  $111.99
# 4  Small Unit Simple Computer Desk Household Wood...        $48.82   $21.37
#
#    sold        tagText
# 0   600  Free shipping
# 1     0  Free shipping
# 2     7  Free shipping
# 3     0  Free shipping
# 4     1  Free shipping

# %%
# tail method 
df.tail()
# Out:
#                                            productTitle originalPrice  \
# 1995  Modern TV Stand Entertainment Center with Two ...           NaN
# 1996  Large Wardrobe Armoire Closet with 3 Doors, Fr...           NaN
# 1997  Velvet Futon Sofa Bed, 73-inch Sleeper Couch w...           NaN
# 1998  Furniture Acrylic Coffee Table Transparent Liv...           NaN
# 1999  Bed Frane Bamboo and Metal Platform Bed Frame ...           NaN
#
#         price  sold        tagText
# 1995   $72.49     8  Free shipping
# 1996  $276.65     2  Free shipping
# 1997  $196.44    10  Free shipping
# 1998  $228.18     0  Free shipping
# 1999   $99.48     0  Free shipping

# %% [markdown]
# ### Now we will check shape, dimension , columns

# %%
df.shape
# Out:
# (2000, 5)

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['productTitle', 'originalPrice', 'price', 'sold', 'tagText'], dtype='object')

# %%
df.dtypes
# Out:
# productTitle     object
# originalPrice    object
# price            object
# sold              int64
# tagText          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   productTitle   2000 non-null   object
#  1   originalPrice  487 non-null    object
#  2   price          2000 non-null   object
#  3   sold           2000 non-null   int64
#  4   tagText        1997 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 78.3+ KB

# %% [markdown]
# ## Handling missing values

# %%
df.isnull().sum()
# Out:
# productTitle        0
# originalPrice    1513
# price               0
# sold                0
# tagText             3
# dtype: int64

# %%
df.isna().sum()
# Out:
# productTitle        0
# originalPrice    1513
# price               0
# sold                0
# tagText             3
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# productTitle     0
# originalPrice    0
# price            0
# sold             0
# tagText          0
# dtype: int64

# %%
df.describe()
# Out:
#                sold
# count   2000.000000
# mean      23.493500
# std      254.094061
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        9.000000
# max    10000.000000

# %%
df.dtypes
# Out:
# productTitle     object
# originalPrice    object
# price            object
# sold              int64
# tagText          object
# dtype: object

# %% [markdown]
# ### Now we will convert object dtype of original price and price in float64 & tagText into category

# %%
df['originalPrice']=df['originalPrice'].str.replace('$','').str.replace(',','')

# %%
df['price']=df['price'].str.replace('$','').str.replace(',','')

# %%
df['originalPrice']=pd.to_numeric(df['originalPrice'])

# %%
df['price']=pd.to_numeric(df['price'])

# %%
df.dtypes
# Out:
# productTitle      object
# originalPrice    float64
# price            float64
# sold               int64
# tagText           object
# dtype: object

# %%
df
# Out:
#                                            productTitle  originalPrice  \
# 0     Dresser For Bedroom With 9 Fabric Drawers Ward...            NaN
# 1     Outdoor Conversation Set 4 Pieces Patio Furnit...            NaN
# 2     Desser For Bedroom With 7 Fabric Drawers Organ...          78.40
# 3     Modern Accent Boucle Chair,Upholstered Tufted ...            NaN
# 4     Small Unit Simple Computer Desk Household Wood...          48.82
# ...                                                 ...            ...
# 1995  Modern TV Stand Entertainment Center with Two ...            NaN
# 1996  Large Wardrobe Armoire Closet with 3 Doors, Fr...            NaN
# 1997  Velvet Futon Sofa Bed, 73-inch Sleeper Couch w...            NaN
# 1998  Furniture Acrylic Coffee Table Transparent Liv...            NaN
# 1999  Bed Frane Bamboo and Metal Platform Bed Frame ...            NaN
#
#        price  sold  tagText
# 0      46.79   600      100
# 1     169.72     0      100
# ...

# %%
df['tagText']=df['tagText'].astype('category').cat.codes

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#                                            productTitle  originalPrice  \
# 0     Dresser For Bedroom With 9 Fabric Drawers Ward...           0.00
# 1     Outdoor Conversation Set 4 Pieces Patio Furnit...           0.00
# 2     Desser For Bedroom With 7 Fabric Drawers Organ...          78.40
# 3     Modern Accent Boucle Chair,Upholstered Tufted ...           0.00
# 4     Small Unit Simple Computer Desk Household Wood...          48.82
# ...                                                 ...            ...
# 1995  Modern TV Stand Entertainment Center with Two ...           0.00
# 1996  Large Wardrobe Armoire Closet with 3 Doors, Fr...           0.00
# 1997  Velvet Futon Sofa Bed, 73-inch Sleeper Couch w...           0.00
# 1998  Furniture Acrylic Coffee Table Transparent Liv...           0.00
# 1999  Bed Frane Bamboo and Metal Platform Bed Frame ...           0.00
#
#        price  sold  tagText
# 0      46.79   600      100
# 1     169.72     0      100
# ...

# %%
df.dtypes
# Out:
# productTitle      object
# originalPrice    float64
# price            float64
# sold               int64
# tagText             int8
# dtype: object

# %% [markdown]
# ### now its good

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
# for original price feature 
plt.boxplot(df['originalPrice'])
plt.show()

# %% [markdown]
# ### As it is not showing the 25 and 75 quartile of range. But we will not remove anything to make it perfect because data is not far range.

# %%
# for price feature
plt.boxplot(df['price'])
plt.show()

# %% [markdown]
# ### wow , its nicely showing pertfect quartile i.e 25 and 75 and also IQR.

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(20,8))
df.groupby('productTitle')["originalPrice"].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='green')
plt.title('Top 10 Product by its originalPrice',size=35)
plt.ylabel('originalPrice($)')
plt.show()

# %% [markdown]
# ### Garden Furniture Set 7 PCS, Garden Fire Pit Table Patio Sets, No-Slip Cushions and Waterproof Covers, Garden Furniture Set' is the most expensive product in terms of original price .  i.e.,(4043.61$)

# %%
plt.figure(figsize=(20,8))
df.groupby('productTitle')["price"].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='cyan')
plt.title('Top 10 Product by its Price',size=35)
plt.ylabel('Price($)')
plt.show()

# %% [markdown]
# ### Garden Furniture Set 7 PCS, Garden Fire Pit Table Patio Sets, No-Slip Cushions and Waterproof Covers, Garden Furniture Set' is the most expensive product in terms of price. i.e.,(3339.50$)

# %%
plt.figure(figsize=(20,8))
df.groupby('productTitle')["sold"].sum().sort_values(ascending=False).head(10).plot(kind='bar',color='coral')
plt.title('Top 10 Product by its Sold Quantity',size=35)
plt.ylabel('Sold Q')
plt.show()

# %% [markdown]
# ### Portable round Folding Chair Accordion Chair Height Adjustment Simple Tool Elephant Swing Playground Queue Chair is the most solded product in quantity. i.e.,(10000)

# %% [markdown]
# ### Creating new feature

# %%
df['Discount_percentage']=((df['originalPrice']-df['price'])/df['originalPrice'])*100

# %%
df
# Out:
#                                            productTitle  originalPrice  \
# 0     Dresser For Bedroom With 9 Fabric Drawers Ward...           0.00
# 1     Outdoor Conversation Set 4 Pieces Patio Furnit...           0.00
# 2     Desser For Bedroom With 7 Fabric Drawers Organ...          78.40
# 3     Modern Accent Boucle Chair,Upholstered Tufted ...           0.00
# 4     Small Unit Simple Computer Desk Household Wood...          48.82
# ...                                                 ...            ...
# 1995  Modern TV Stand Entertainment Center with Two ...           0.00
# 1996  Large Wardrobe Armoire Closet with 3 Doors, Fr...           0.00
# 1997  Velvet Futon Sofa Bed, 73-inch Sleeper Couch w...           0.00
# 1998  Furniture Acrylic Coffee Table Transparent Liv...           0.00
# 1999  Bed Frane Bamboo and Metal Platform Bed Frame ...           0.00
#
#        price  sold  tagText  Discount_percentage
# 0      46.79   600      100                 -inf
# ...

# %% [markdown]
# ### -inf: no discount

# %%
df.to_csv('C:/Users/sunde/OneDrive/Desktop/project3/ecommerce_furniture_dataset_2024.csv')

# %% [markdown]
# ## Project By

# %% [markdown]
# ### Shailendra Patel

# %% [markdown]
# ### Thank You 😊🤗
